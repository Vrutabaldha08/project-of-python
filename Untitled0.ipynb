# %% [markdown]
# <a href="https://colab.research.google.com/github/Vrutabaldha08/project-of-python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Convert km into miles

# %%
#collection of km
km = float(input("enter kilometre: "))

#conversion factor
conv_factor = 0.621371

#calculate in miles
miles = km * conv_factor

#print km in miles
print('%0.3f km is equal %0.3f miles' %(km,miles))
# Out:
# enter kilometre: 4
# 4.000 km is equal 2.485 miles

# %% [markdown]
# # Convert miles into km

# %%
#collection of miles
miles = float(input("enter miles: "))

#conversion factor
conv_factor = 0.621371

#calculate in km
km = miles / conv_factor

#print miles in km
print('%0.3f miles is equal %0.3f km' %(miles,km))
# Out:
# enter miles: 44
# 44.000 miles is equal 70.811 km
